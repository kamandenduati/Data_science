# %%
import pandas as pd
import numpy as np
import seaborn as sns
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Survey = sorted(glob('file/IT*.csv'))

# %%
survey=pd.concat((pd.read_csv(file) for file in Survey),ignore_index=True)

# %%
survey.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 30 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                2018 non-null   object
#  1   Age                                                                                                                      1898 non-null   float64
#  2   Gender                                                                                                                   1994 non-null   object
# ...

# %%
survey.isnull().sum()
# Out:
# Timestamp                                                                                                                     0
# Age                                                                                                                         120
# Gender                                                                                                                       24
# City                                                                                                                         29
# Position                                                                                                                    771
# Total years of experience                                                                                                   781
# Years of experience in Germany                                                                                              797
# ...

# %%
survey.dropna()
# Out:
# Empty DataFrame
# ...

# %%
survey.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1898.000000                                       1.253000e+03
# mean     32.394099                                       8.027904e+07
# std       5.474107                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
sns.histplot(data=survey,x='Current Salary')
plt.title("Current Salary")
plt.show()

# %%
sns.histplot(data=survey,x='Salary one Timestamp ago')
plt.title("Salary one Timestamp ago")
plt.show()

# %%
sns.histplot(data=survey,x='Salary two Timestamps ago')
plt.title("Salary two Timestamps ago")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=survey, x='Current Salary', y='Gender')
plt.title('Distribution of Salary by Gender')
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=survey, x='Age', y='Current Salary')
plt.title('Distribution of Salary by age')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=survey, x='Years of experience', y='Current Salary')
plt.title('Salary vs. Years of Experience')
plt.show()

# %%
plt.figure(figsize=(12,8))
corr = survey.corr()
sns.heatmap(corr, cmap='viridis', annot=True)
plt.title('Correlation matrix')
plt.show()
